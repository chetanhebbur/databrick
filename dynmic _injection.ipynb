# %%
dbutils.widgets.text("file","")

# %%
dbutils.widgets.get("file")

# %%
df=spark.read.format("csv").option("header","true").option("inferSchema","true").load("/Volumes/dbinterview/source/source_order/{file}")

df.write.mode("overwrite").format("delta").save("/Volumes/dbinterview/source/dynmic/{file}")
