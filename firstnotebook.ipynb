# %%
#create sample dataframe
data = [("Alice", 34), ("Bob", 45), ("Charlie", 29)]
columns = ["Name", "Age"]
df = spark.createDataFrame(data, columns)
display(df)

# %%
for i in df.collect():
    if i.Age > 30 and i.Name == "Bob":
        print(i)
